# %% [markdown]
# # Kode Fungsi

# %%
import pandas as pd

def data_imputer(strategy='mean'):
    def impute(data):
        if isinstance(data, pd.DataFrame):
            for column in data.columns:
                if pd.api.types.is_numeric_dtype(data[column]):
                    if strategy == 'mean':
                        data[column] = data[column].fillna(data[column].mean())
                    elif strategy == 'median':
                        data[column] = data[column].fillna(data[column].median())
                    elif strategy == 'mode':
                        data[column] = data[column].fillna(data[column].mode()[0])
                    else:
                        raise ValueError("Unsupported imputation strategy")
        elif isinstance(data, pd.Series):
            if pd.api.types.is_numeric_dtype(data):
                if strategy == 'mean':
                    data = data.fillna(data.mean())
                elif strategy == 'median':
                    data = data.fillna(data.median())
                elif strategy == 'mode':
                    data = data.fillna(data.mode()[0])
                else:
                    raise ValueError("Unsupported imputation strategy")
        else:
            raise ValueError("Unsupported data type. Expecting Pandas DataFrame or Series.")
        return data

    return impute

# %% [markdown]
# # Penerapan pada dataset

# %%
import pandas as pd
data = pd.read_excel("/content/pbf.xlsx")

# %%
data
# Out:
#         Bulan Jumlah Curah Hujan  Rata-rata Suhu Udara  \
# 0     Januari             Tinggi                  34.2
# 1    Februari           Menengah                  34.4
# 2       Maret           Menengah                  34.6
# 3       April           Menengah                   NaN
# 4         Mei           Menengah                  35.0
# 5        Juni           Menengah                  34.2
# 6        Juli             Rendah                  33.4
# 7     Agustus           Menengah                  34.2
# 8   September             Rendah                  34.0
# 9     Oktober           Menengah                  34.4
# 10   November           Menengah                  35.0
# 11   Desember           Menengah                  33.6
#
#     Rata-rata Kelembaban Udara
# 0                        100.0
# 1                        100.0
# 2                        100.0
# 3                         98.0
# 4                        100.0
# 5                          NaN
# 6                         98.0
# 7                         98.0
# 8                         96.0
# 9                         98.0
# 10                        99.0
# 11                       100.0

# %%
data.isnull().sum()
# Out:
# Bulan                         0
# Jumlah Curah Hujan            0
# Rata-rata Suhu Udara          1
# Rata-rata Kelembaban Udara    1
# dtype: int64

# %%
impute_mean = data_imputer()
data_imputed = impute_mean(data)

# %%
data_imputed
# Out:
#         Bulan Jumlah Curah Hujan  Rata-rata Suhu Udara  \
# 0     Januari             Tinggi             34.200000
# 1    Februari           Menengah             34.400000
# 2       Maret           Menengah             34.600000
# 3       April           Menengah             34.272727
# 4         Mei           Menengah             35.000000
# 5        Juni           Menengah             34.200000
# 6        Juli             Rendah             33.400000
# 7     Agustus           Menengah             34.200000
# 8   September             Rendah             34.000000
# 9     Oktober           Menengah             34.400000
# 10   November           Menengah             35.000000
# 11   Desember           Menengah             33.600000
#
#     Rata-rata Kelembaban Udara
# 0                   100.000000
# 1                   100.000000
# 2                   100.000000
# 3                    98.000000
# 4                   100.000000
# 5                    98.818182
# 6                    98.000000
# 7                    98.000000
# 8                    96.000000
# 9                    98.000000
# 10                   99.000000
# 11                  100.000000

# %%
impute_median = data_imputer('median')
impute_median(data)
# Out:
#         Bulan Jumlah Curah Hujan  Rata-rata Suhu Udara  \
# 0     Januari             Tinggi                  34.2
# 1    Februari           Menengah                  34.4
# 2       Maret           Menengah                  34.6
# 3       April           Menengah                  34.2
# 4         Mei           Menengah                  35.0
# 5        Juni           Menengah                  34.2
# 6        Juli             Rendah                  33.4
# 7     Agustus           Menengah                  34.2
# 8   September             Rendah                  34.0
# 9     Oktober           Menengah                  34.4
# 10   November           Menengah                  35.0
# 11   Desember           Menengah                  33.6
#
#     Rata-rata Kelembaban Udara
# 0                        100.0
# 1                        100.0
# 2                        100.0
# 3                         98.0
# 4                        100.0
# 5                         99.0
# 6                         98.0
# 7                         98.0
# 8                         96.0
# 9                         98.0
# 10                        99.0
# 11                       100.0

# %%
impute_mode = data_imputer('mode')
impute_mode(data)
# Out:
#         Bulan Jumlah Curah Hujan  Rata-rata Suhu Udara  \
# 0     Januari             Tinggi                  34.2
# 1    Februari           Menengah                  34.4
# 2       Maret           Menengah                  34.6
# 3       April           Menengah                  34.2
# 4         Mei           Menengah                  35.0
# 5        Juni           Menengah                  34.2
# 6        Juli             Rendah                  33.4
# 7     Agustus           Menengah                  34.2
# 8   September             Rendah                  34.0
# 9     Oktober           Menengah                  34.4
# 10   November           Menengah                  35.0
# 11   Desember           Menengah                  33.6
#
#     Rata-rata Kelembaban Udara
# 0                        100.0
# 1                        100.0
# 2                        100.0
# 3                         98.0
# 4                        100.0
# 5                        100.0
# 6                         98.0
# 7                         98.0
# 8                         96.0
# 9                         98.0
# 10                        99.0
# 11                       100.0
